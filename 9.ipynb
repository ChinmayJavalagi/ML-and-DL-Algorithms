# %% [markdown]
# ### 9.	Implement a CNN architecture using Pytorch and understand the importance of various functions in CNN (Conv, pooling, Relu, SoftMax). Implement a 5-class classifier using any data to train a LeNet-5, VGG-16, and ResNet-18 architecture

# %% [markdown]
# # LeNET5

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms

# %%
batch_size = 64
num_classes = 10
learning_rate = 0.001
num_epochs = 10

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
train_dataset = torchvision.datasets.MNIST(root = './data',
                                           train = True,
                                           transform = transforms.Compose([
                                                  transforms.Resize((32,32)),
                                                  transforms.ToTensor(),
                                                  transforms.Normalize(mean = (0.1307,), std = (0.3081,))]),
                                           download = True)


test_dataset = torchvision.datasets.MNIST(root = './data',
                                          train = False,
                                          transform = transforms.Compose([
                                                  transforms.Resize((32,32)),
                                                  transforms.ToTensor(),
                                                  transforms.Normalize(mean = (0.1325,), std = (0.3105,))]),
                                          download=True)


train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           shuffle = True)


test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                           batch_size = batch_size,
                                           shuffle = True)

# %%
#Defining the convolutional neural network
class LeNet5(nn.Module):
    def __init__(self, num_classes):
        super(LeNet5, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 6, kernel_size=5, stride=1, padding=0),
            nn.BatchNorm2d(6),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2, stride = 2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(6, 16, kernel_size=5, stride=1, padding=0),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2, stride = 2))
        self.fc = nn.Linear(400, 120)
        self.relu = nn.ReLU()
        self.fc1 = nn.Linear(120, 84)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(84, num_classes)
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        out = self.relu(out)
        out = self.fc1(out)
        out = self.relu1(out)
        out = self.fc2(out)
        return out

# %%
model = LeNet5(num_classes).to(device)

cost = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

total_step = len(train_loader)

# %%
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):  
        images = images.to(device)
        labels = labels.to(device)
        
        #Forward pass
        outputs = model(images)
        loss = cost(outputs, labels)
        	
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        		
        if (i+1) % 400 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
        		           .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
# Out:
# Epoch [1/10], Step [400/938], Loss: 0.0577
# Epoch [1/10], Step [800/938], Loss: 0.0157
# Epoch [2/10], Step [400/938], Loss: 0.0243
# Epoch [2/10], Step [800/938], Loss: 0.0481
# Epoch [3/10], Step [400/938], Loss: 0.0057
# Epoch [3/10], Step [800/938], Loss: 0.0103
# Epoch [4/10], Step [400/938], Loss: 0.0182
# Epoch [4/10], Step [800/938], Loss: 0.0100
# Epoch [5/10], Step [400/938], Loss: 0.0493
# Epoch [5/10], Step [800/938], Loss: 0.0126
# Epoch [6/10], Step [400/938], Loss: 0.0144
# Epoch [6/10], Step [800/938], Loss: 0.0506
# Epoch [7/10], Step [400/938], Loss: 0.0113
# Epoch [7/10], Step [800/938], Loss: 0.0017
# Epoch [8/10], Step [400/938], Loss: 0.0106
# Epoch [8/10], Step [800/938], Loss: 0.0009
# Epoch [9/10], Step [400/938], Loss: 0.0448
# Epoch [9/10], Step [800/938], Loss: 0.0005
# Epoch [10/10], Step [400/938], Loss: 0.0045
# Epoch [10/10], Step [800/938], Loss: 0.0136

# %%
with torch.no_grad():
  correct = 0
  total = 0
  for images, labels in test_loader:
    images = images.to(device)
    labels = labels.to(device)
    outputs = model(images)
    _,predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum().item()
    
    print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 98.4375 %
# Accuracy of the network on the 10000 test images: 98.4375 %
# Accuracy of the network on the 10000 test images: 98.95833333333333 %
# Accuracy of the network on the 10000 test images: 98.828125 %
# Accuracy of the network on the 10000 test images: 99.0625 %
# Accuracy of the network on the 10000 test images: 99.21875 %
# Accuracy of the network on the 10000 test images: 99.33035714285714 %
# Accuracy of the network on the 10000 test images: 99.21875 %
# Accuracy of the network on the 10000 test images: 99.13194444444444 %
# Accuracy of the network on the 10000 test images: 99.0625 %
# Accuracy of the network on the 10000 test images: 99.14772727272727 %
# Accuracy of the network on the 10000 test images: 99.08854166666667 %
# Accuracy of the network on the 10000 test images: 99.15865384615384 %
# Accuracy of the network on the 10000 test images: 99.21875 %
# Accuracy of the network on the 10000 test images: 99.16666666666667 %
# Accuracy of the network on the 10000 test images: 99.21875 %
# Accuracy of the network on the 10000 test images: 99.26470588235294 %
# Accuracy of the network on the 10000 test images: 99.30555555555556 %
# Accuracy of the network on the 10000 test images: 99.25986842105263 %
# Accuracy of the network on the 10000 test images: 99.21875 %
# Accuracy of the network on the 10000 test images: 99.25595238095238 %
# Accuracy of the network on the 10000 test images: 99.14772727272727 %
# Accuracy of the network on the 10000 test images: 99.18478260869566 %
# Accuracy of the network on the 10000 test images: 99.21875 %
# Accuracy of the network on the 10000 test images: 99.1875 %
# Accuracy of the network on the 10000 test images: 99.0985576923077 %
# Accuracy of the network on the 10000 test images: 99.13194444444444 %
# Accuracy of the network on the 10000 test images: 99.16294642857143 %
# Accuracy of the network on the 10000 test images: 99.08405172413794 %
# Accuracy of the network on the 10000 test images: 99.11458333333333 %
# Accuracy of the network on the 10000 test images: 99.14314516129032 %
# Accuracy of the network on the 10000 test images: 99.072265625 %
# Accuracy of the network on the 10000 test images: 99.10037878787878 %
# Accuracy of the network on the 10000 test images: 99.08088235294117 %
# Accuracy of the network on the 10000 test images: 99.01785714285714 %
# Accuracy of the network on the 10000 test images: 99.04513888888889 %
# Accuracy of the network on the 10000 test images: 99.07094594594595 %
# Accuracy of the network on the 10000 test images: 99.09539473684211 %
# Accuracy of the network on the 10000 test images: 99.03846153846153 %
# Accuracy of the network on the 10000 test images: 99.0625 %
# Accuracy of the network on the 10000 test images: 99.04725609756098 %
# Accuracy of the network on the 10000 test images: 99.06994047619048 %
# Accuracy of the network on the 10000 test images: 99.05523255813954 %
# Accuracy of the network on the 10000 test images: 99.07670454545455 %
# Accuracy of the network on the 10000 test images: 99.02777777777777 %
# Accuracy of the network on the 10000 test images: 99.0149456521739 %
# Accuracy of the network on the 10000 test images: 99.03590425531915 %
# Accuracy of the network on the 10000 test images: 99.05598958333333 %
# Accuracy of the network on the 10000 test images: 99.04336734693878 %
# Accuracy of the network on the 10000 test images: 99.0625 %
# Accuracy of the network on the 10000 test images: 99.05024509803921 %
# Accuracy of the network on the 10000 test images: 99.06850961538461 %
# Accuracy of the network on the 10000 test images: 99.08608490566037 %
# Accuracy of the network on the 10000 test images: 99.10300925925925 %
# Accuracy of the network on the 10000 test images: 99.11931818181819 %
# Accuracy of the network on the 10000 test images: 99.13504464285714 %
# Accuracy of the network on the 10000 test images: 99.15021929824562 %
# Accuracy of the network on the 10000 test images: 99.16487068965517 %
# Accuracy of the network on the 10000 test images: 99.15254237288136 %
# Accuracy of the network on the 10000 test images: 99.11458333333333 %
# Accuracy of the network on the 10000 test images: 99.05225409836065 %
# Accuracy of the network on the 10000 test images: 99.06754032258064 %
# Accuracy of the network on the 10000 test images: 99.08234126984127 %
# Accuracy of the network on the 10000 test images: 99.0966796875 %
# Accuracy of the network on the 10000 test images: 99.11057692307692 %
# Accuracy of the network on the 10000 test images: 99.12405303030303 %
# Accuracy of the network on the 10000 test images: 99.11380597014926 %
# Accuracy of the network on the 10000 test images: 99.12683823529412 %
# Accuracy of the network on the 10000 test images: 99.13949275362319 %
# Accuracy of the network on the 10000 test images: 99.12946428571429 %
# Accuracy of the network on the 10000 test images: 99.14172535211267 %
# Accuracy of the network on the 10000 test images: 99.08854166666667 %
# Accuracy of the network on the 10000 test images: 99.10102739726027 %
# Accuracy of the network on the 10000 test images: 99.11317567567568 %
# Accuracy of the network on the 10000 test images: 99.10416666666667 %
# Accuracy of the network on the 10000 test images: 99.11595394736842 %
# Accuracy of the network on the 10000 test images: 99.10714285714286 %
# Accuracy of the network on the 10000 test images: 99.0985576923077 %
# Accuracy of the network on the 10000 test images: 99.10996835443038 %
# Accuracy of the network on the 10000 test images: 99.12109375 %
# Accuracy of the network on the 10000 test images: 99.13194444444444 %
# Accuracy of the network on the 10000 test images: 99.1234756097561 %
# Accuracy of the network on the 10000 test images: 99.13403614457832 %
# Accuracy of the network on the 10000 test images: 99.14434523809524 %
# Accuracy of the network on the 10000 test images: 99.13602941176471 %
# Accuracy of the network on the 10000 test images: 99.12790697674419 %
# Accuracy of the network on the 10000 test images: 99.13793103448276 %
# Accuracy of the network on the 10000 test images: 99.1299715909091 %
# Accuracy of the network on the 10000 test images: 99.13974719101124 %
# Accuracy of the network on the 10000 test images: 99.13194444444444 %
# Accuracy of the network on the 10000 test images: 99.10714285714286 %
# Accuracy of the network on the 10000 test images: 99.09986413043478 %
# Accuracy of the network on the 10000 test images: 99.10954301075269 %
# Accuracy of the network on the 10000 test images: 99.10239361702128 %
# Accuracy of the network on the 10000 test images: 99.07894736842105 %
# Accuracy of the network on the 10000 test images: 99.072265625 %
# Accuracy of the network on the 10000 test images: 99.08182989690722 %
# Accuracy of the network on the 10000 test images: 99.07525510204081 %
# Accuracy of the network on the 10000 test images: 99.06881313131314 %
# Accuracy of the network on the 10000 test images: 99.078125 %
# Accuracy of the network on the 10000 test images: 99.05631188118812 %
# Accuracy of the network on the 10000 test images: 99.05024509803921 %
# Accuracy of the network on the 10000 test images: 99.04429611650485 %
# Accuracy of the network on the 10000 test images: 99.0234375 %
# Accuracy of the network on the 10000 test images: 99.0327380952381 %
# Accuracy of the network on the 10000 test images: 99.02712264150944 %
# Accuracy of the network on the 10000 test images: 99.02161214953271 %
# Accuracy of the network on the 10000 test images: 99.03067129629629 %
# Accuracy of the network on the 10000 test images: 99.02522935779817 %
# Accuracy of the network on the 10000 test images: 99.01988636363636 %
# Accuracy of the network on the 10000 test images: 99.01463963963964 %
# Accuracy of the network on the 10000 test images: 99.0234375 %
# Accuracy of the network on the 10000 test images: 99.00442477876106 %
# Accuracy of the network on the 10000 test images: 98.99945175438596 %
# Accuracy of the network on the 10000 test images: 99.00815217391305 %
# Accuracy of the network on the 10000 test images: 98.98976293103448 %
# Accuracy of the network on the 10000 test images: 98.98504273504274 %
# Accuracy of the network on the 10000 test images: 98.98040254237289 %
# Accuracy of the network on the 10000 test images: 98.98897058823529 %
# Accuracy of the network on the 10000 test images: 98.95833333333333 %
# Accuracy of the network on the 10000 test images: 98.95402892561984 %
# Accuracy of the network on the 10000 test images: 98.9626024590164 %
# Accuracy of the network on the 10000 test images: 98.95833333333333 %
# Accuracy of the network on the 10000 test images: 98.94153225806451 %
# Accuracy of the network on the 10000 test images: 98.95 %
# Accuracy of the network on the 10000 test images: 98.94593253968254 %
# Accuracy of the network on the 10000 test images: 98.94192913385827 %
# Accuracy of the network on the 10000 test images: 98.93798828125 %
# Accuracy of the network on the 10000 test images: 98.93410852713178 %
# Accuracy of the network on the 10000 test images: 98.93028846153847 %
# Accuracy of the network on the 10000 test images: 98.92652671755725 %
# Accuracy of the network on the 10000 test images: 98.92282196969697 %
# Accuracy of the network on the 10000 test images: 98.91917293233082 %
# Accuracy of the network on the 10000 test images: 98.91557835820896 %
# Accuracy of the network on the 10000 test images: 98.92361111111111 %
# Accuracy of the network on the 10000 test images: 98.90854779411765 %
# Accuracy of the network on the 10000 test images: 98.91651459854015 %
# Accuracy of the network on the 10000 test images: 98.92436594202898 %
# Accuracy of the network on the 10000 test images: 98.93210431654676 %
# Accuracy of the network on the 10000 test images: 98.93973214285714 %
# Accuracy of the network on the 10000 test images: 98.94725177304964 %
# Accuracy of the network on the 10000 test images: 98.94366197183099 %
# Accuracy of the network on the 10000 test images: 98.95104895104895 %
# Accuracy of the network on the 10000 test images: 98.95833333333333 %
# Accuracy of the network on the 10000 test images: 98.95474137931035 %
# Accuracy of the network on the 10000 test images: 98.9619006849315 %
# Accuracy of the network on the 10000 test images: 98.95833333333333 %
# Accuracy of the network on the 10000 test images: 98.96537162162163 %
# Accuracy of the network on the 10000 test images: 98.9618288590604 %
# Accuracy of the network on the 10000 test images: 98.96875 %
# Accuracy of the network on the 10000 test images: 98.97557947019868 %
# Accuracy of the network on the 10000 test images: 98.9720394736842 %
# Accuracy of the network on the 10000 test images: 98.95833333333333 %
# Accuracy of the network on the 10000 test images: 98.96509740259741 %
# Accuracy of the network on the 10000 test images: 98.9616935483871 %
# Accuracy of the network on the 10000 test images: 98.93830128205128 %
# Accuracy of the network on the 10000 test images: 98.93 %

# %% [markdown]
# # VGG16

# %%
import numpy as np
import torch
import torch.nn as nn
import torchvision
from torchvision import datasets
from torchvision import transforms
from torch.utils.data.sampler import SubsetRandomSampler


# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
train_dataset = torchvision.datasets.MNIST(root = './data',
                                           train = True,
                                           transform = transforms.Compose([
                                                  transforms.Resize((32,32)),
                                                  transforms.ToTensor(),
                                                  transforms.Normalize(mean = (0.1307,), std = (0.3081,))]),
                                           download = True)


test_dataset = torchvision.datasets.MNIST(root = './data',
                                          train = False,
                                          transform = transforms.Compose([
                                                  transforms.Resize((32,32)),
                                                  transforms.ToTensor(),
                                                  transforms.Normalize(mean = (0.1325,), std = (0.3105,))]),
                                          download=True)


train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           shuffle = True)


test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                           batch_size = batch_size,
                                           shuffle = True)

# %%
class VGG16(nn.Module):
    def __init__(self, num_classes=10):
        super(VGG16, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU())
        self.layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(), 
            nn.MaxPool2d(kernel_size = 2, stride = 2))
        self.layer3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU())
        self.layer4 = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2, stride = 2))
        self.layer5 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU())
        self.layer6 = nn.Sequential(
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU())
        self.layer7 = nn.Sequential(
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2, stride = 2))
        self.layer8 = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU())
        self.layer9 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU())
        self.layer10 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2, stride = 2))
        self.layer11 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU())
        self.layer12 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU())
        self.layer13 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2, stride = 2))
        self.fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(7*7*512, 4096),
            nn.ReLU())
        self.fc1 = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU())
        self.fc2= nn.Sequential(
            nn.Linear(4096, num_classes))
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = self.layer6(out)
        out = self.layer7(out)
        out = self.layer8(out)
        out = self.layer9(out)
        out = self.layer10(out)
        out = self.layer11(out)
        out = self.layer12(out)
        out = self.layer13(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# %%
# num_classes = 100
# num_epochs = 20
# batch_size = 16
# learning_rate = 0.005

# model = VGG16(num_classes).to(device)


# # Loss and optimizer
# criterion = nn.CrossEntropyLoss()
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay = 0.005, momentum = 0.9)  


# # Train the model
# total_step = len(train_loader)

model = VGG16(num_classes).to(device)

cost = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

total_step = len(train_loader)

# %%
total_step = len(train_loader)

# for epoch in range(num_epochs):
#     for i, (images, labels) in enumerate(train_loader):  
#         # Move tensors to the configured device
#         images = images.to(device)
#         labels = labels.to(device)
        
#         # Forward pass
#         outputs = model(images)
#         loss = criterion(outputs, labels)
        
#         # Backward and optimize
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()

#     print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
#                    .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
            
#     # Validation
#     with torch.no_grad():
#         correct = 0
#         total = 0
#         for images, labels in valid_loader:
#             images = images.to(device)
#             labels = labels.to(device)
#             outputs = model(images)
#             _, predicted = torch.max(outputs.data, 1)
#             total += labels.size(0)
#             correct += (predicted == labels).sum().item()
#             del images, labels, outputs
    
#         print('Accuracy of the network on the {} validation images: {} %'.format(5000, 100 * correct / total)) 


total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):  
        images = images.to(device)
        labels = labels.to(device)
        
        #Forward pass
        outputs = model(images)
        loss = cost(outputs, labels)
        	
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        		
        if (i+1) % 400 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
        		           .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-bf7827338beb> in <module>
#      42
#      43         #Forward pass
# ---> 44         outputs = model(images)
#      45         loss = cost(outputs, labels)
#      46
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-20-b91552dab5c6> in forward(self, x)
#      85         out = self.layer13(out)
#      86         out = out.reshape(out.size(0), -1)
# ---> 87         out = self.fc(out)
#      88         out = self.fc1(out)
#      89         out = self.fc2(out)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (64x512 and 25088x4096)

# %%
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        del images, labels, outputs

    print('Accuracy of the network on the {} test images: {} %'.format(10000, 100 * correct / total))
